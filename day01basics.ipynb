# %% [markdown]
# <a href="https://colab.research.google.com/github/Farhan1Ahmed1Molla/EE-Finance-AI-Journey/blob/main/day01basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Day 1 - Python basics

# %%
## Age calculator

# %%
age = int(input("Enter your age:"))
print("After five years you will be =",age+5)

# %%
## Simple Interest Calculator

# %%
p = float(input("principal:"))
r = float(input("rate:"))
t = float(input("time:"))
si = (p * r * t) / 100
print("Simple interest =",si)

# %%
## Ohm's law calculator

# %%
resistance = float(input("Resistance:"))
voltage = float(input("Voltage:"))
Current = voltage / resistance
print("current=",Current)
