# %% [markdown]
# <a href="https://colab.research.google.com/github/Farhan1Ahmed1Molla/EE-Finance-AI-Journey/blob/main/day012_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Guessing game

# %%
def guess_number():
     guess = int(input("Enter number:  "))
     while guess != 7:
            print("Wrong,please try again")
            guess = int(input("Enter number:  "))
     print("Found")

guess_number()
# Out:
# Enter number:  8
# Wrong,please try again
# Enter number:  7
# Found
