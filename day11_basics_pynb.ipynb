# %% [markdown]
# <a href="https://colab.research.google.com/github/Farhan1Ahmed1Molla/EE-Finance-AI-Journey/blob/main/day11_basics_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Name printer new design

# %%
def print_prices(prices):
    number = 1
    for item in prices:

        print(f"{number}.{item}")
        number += 1
print_prices([70,80,90,100,110])
# Out:
# 1.70
# 2.80
# 3.90
# 4.100
# 5.110
