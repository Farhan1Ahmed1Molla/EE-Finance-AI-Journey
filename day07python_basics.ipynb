# %% [markdown]
# <a href="https://colab.research.google.com/github/Farhan1Ahmed1Molla/EE-Finance-AI-Journey/blob/main/day07python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Football team selector

# %%
Team = ["Salah","Halaand","Bellingham","Rodri"]

for item in Team :
  print(item)

players = input("Enter player = ")

if players in Team:
  print("selected")

else:
  print("Not found")
# Out:
# Salah
# Halaand
# Bellingham
# Rodri
# Enter player = Halaand
# selected

# %%
## Average Marks calculator

# %%
math = int(input(" Enter Math marks: "))
physics = int(input(" Enter Physics marks: "))
chemistry =int(input(" Enter Chemistry marks: "))

def calculate_average(mark1, mark2, mark3):
    return (mark1 + mark2 + mark3) / 3

Average = calculate_average(math,physics,chemistry)
print(Average)

if Average >= 80:
   print("Excellent")

elif Average >= 60:
   print("Good")

elif Average >= 40:
   print("You need to improve")

else:
   print("You failed")
# Out:
#  Enter Math marks: 20
#  Enter Physics marks: 24
#  Enter Chemistry marks: 33
# 25.666666666666668
# You failed

# %%
## Electrical components counter

# %%
components = ["Resistor","Capacitor","Inductor","Transformer"]

number = 1

for item in components:
    print(f"{number}. {item}")
    number = number + 1

def count_components():
    count = 0

    for item in components:
       count = count + 1
    return count

print(f"Total number of components = {count}")
# Out:
# 1. Resistor
# 2. Capacitor
# 3. Inductor
# 4. Transformer
# Total number of components = 4
