# %% [markdown]
# <a href="https://colab.research.google.com/github/Farhan1Ahmed1Molla/EE-Finance-AI-Journey/blob/main/day03_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Voting eligibility checker

# %%
age = int(input(" Enter your age:"))
if age >= 18:
    print(" you can vote ")
else:
    print("you cannot vote ")
# Out:
#  Enter your age:12
# you cannot vote

# %%
## Number counter from 1 to 10

# %%
for i in range(1,11):
    print("Number =",i)
# Out:
# Number = 1
# Number = 2
# Number = 3
# Number = 4
# Number = 5
# Number = 6
# Number = 7
# Number = 8
# Number = 9
# Number = 10

# %%
## Multiplication table

# %%
Number = int(input("Enter a number:"))
for i in range(1,11):
  print(f"{Number} × {i} = {Number * i}")
# Out:
# Enter a number:5
# 5 × 1 = 5
# 5 × 2 = 10
# 5 × 3 = 15
# 5 × 4 = 20
# 5 × 5 = 25
# 5 × 6 = 30
# 5 × 7 = 35
# 5 × 8 = 40
# 5 × 9 = 45
# 5 × 10 = 50

# %%
## Power Calculator

# %%
Voltage = int(input("Enter volts:"))
Current = int(input("Enter current:"))
print(f"Power = {Voltage * Current} W")
# Out:
# Enter volts:230
# Enter current:5
# Power = 1150 W

# %%
## Study Hours tracker

# %%
Hours = int(input("Enter study time:"))
print(f"You studied {Hours} today.")
if Hours >= 3:
 print(" Good job")
else:
 print("Try harder")
# Out:
# Enter study time:1
# You studied 1 today.
# Try harder
