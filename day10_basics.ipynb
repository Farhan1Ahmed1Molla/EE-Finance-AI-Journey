# %% [markdown]
# <a href="https://colab.research.google.com/github/Farhan1Ahmed1Molla/EE-Finance-AI-Journey/blob/main/day10_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Average calculator

# %%
physics = int( input(" Enter Physics marks: "))
chemistry = int(input("Enter Chemistry marks: "))
maths = int(input("Enter maths marks: "))
biology = int(input("Enter biology marks: "))

def calculate_average():
    return (physics + chemistry + maths + biology) / 4

result = calculate_average()

print(f"Average percentage = {result}")

if result >= 70:
    print("Distinction")
elif result >= 50:
    print("Pass")
else:
    print("Fail")
# Out:
#  Enter Physics marks: 70
# Enter Chemistry marks: 80
# Enter maths marks: 90
# Enter biology marks: 60
# Average percentage = 75.0
# Distinction
