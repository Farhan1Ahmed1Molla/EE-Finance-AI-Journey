# %% [markdown]
# <a href="https://colab.research.google.com/github/Farhan1Ahmed1Molla/EE-Finance-AI-Journey/blob/main/day13_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Double multiplication table

# %%
for table in range(1,11):
    for item in range(1,3,):
        print(f"{item} × {table} = {item * table}")
# Out:
# 1 × 1 = 1
# 2 × 1 = 2
# 1 × 2 = 2
# 2 × 2 = 4
# 1 × 3 = 3
# 2 × 3 = 6
# 1 × 4 = 4
# 2 × 4 = 8
# 1 × 5 = 5
# 2 × 5 = 10
# 1 × 6 = 6
# 2 × 6 = 12
# 1 × 7 = 7
# 2 × 7 = 14
# 1 × 8 = 8
# 2 × 8 = 16
# 1 × 9 = 9
# 2 × 9 = 18
# 1 × 10 = 10
# 2 × 10 = 20
