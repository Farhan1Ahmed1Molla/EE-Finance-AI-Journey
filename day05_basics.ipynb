# %% [markdown]
# <a href="https://colab.research.google.com/github/Farhan1Ahmed1Molla/EE-Finance-AI-Journey/blob/main/day05_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Student list viewer (Part 1)

# %%
student = ['Ali','uthman','Umar']


print("Student List")
print(student)
print(f"Student no 1 = {student[0]}")
print(f"Student no 2 = {student[1]}")
print(f"Student no 3 = {student[2]}")
# Out:
# Student List
# ['Ali', 'uthman', 'Umar']
# Student no 1 = Ali
# Student no 2 = uthman
# Student no 3 = Umar

# %%
## Study list updated (Part 2)

# %%
student = ["Ali","uthman","Umar"]
student.append("Abu bakr")


print("Student List")
print(student)
print(f"Student no 1 = {student[0]}")
print(f"Student no 2 = {student[1]}")
print(f"Student no 3 = {student[2]}")
print(f"Student no 4 = {student[3]}")
# Out:
# Student List
# ['Ali', 'uthman', 'Umar', 'Abu bakr']
# Student no 1 = Ali
# Student no 2 = uthman
# Student no 3 = Umar
# Student no 4 = Abu bakr

# %%
## Student list printer (Part 3)

# %%
student = ["Ali","Uthman","Umar"]
student.append("Abu bakr")

for item in student:
 print(f"Student = {item} ")
# Out:
# Student = Ali
# Student = Uthman
# Student = Umar
# Student = Abu bakr

# %%
## Grocery list tracker

# %%
grocery = ["potato","onion","cabbage","eggs"]
number = 1
for item in grocery:

  print(f"{number}.{item}")
  number = number+1
# Out:
# 1.potato
# 2.onion
# 3.cabbage
# 4.eggs
