# %% [markdown]
# <a href="https://colab.research.google.com/github/Farhan1Ahmed1Molla/EE-Finance-AI-Journey/blob/main/day04_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Greeting function
# Out:
# Hello
# Farhan

# %%
def greet():
   print("Hello")
   print("Farhan")


greet()
greet()
# Out:
# Hello
# Farhan
# Hello
# Farhan

# %%
def greet_student(name):
    print(f"Hello {name}")


greet_student("Farhan")
greet_student("Ahmed")
greet_student("Molla")
# Out:
# Hello Farhan
# Hello Ahmed
# Hello Molla

# %%
## Square calculator

# %%
def square(number):
    return number * number
print (square(5))
# Out:
# 25

# %%
## Power calculator

# %%
def calculate_power(voltage,current):
    return voltage * current
print (f"100V × 3A = {calculate_power(100,3)}W")
# Out:
# 100V × 3A = 300W
